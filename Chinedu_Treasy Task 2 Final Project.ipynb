# %%
#define the variable
url ='https://api.jcdecaux.com/vls/v3/stations?contract=luxembourg&apiKey=2086618fd56f440495359ec40aafbefbfd76bf62'

# %%
import pandas as pd
import numpy as np 
from pandas import Series, DataFrame

# %%
import requests

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
df=pd.DataFrame(data)

# %%
df.to_csv("Sat22  12 NOON.csv")

# %%
df
# Out:
#      number contractName                         name  \
# 0        53   luxembourg  #00053-LUDWIG VAN BEETHOVEN
# 1        24   luxembourg               #00024-WEICKER
# 2       102   luxembourg        #00102-FENTANGE HIEHL
# 3        88   luxembourg                 #00088-SERRA
# 4         6   luxembourg              #00006-AL BRÉCK
# ..      ...          ...                          ...
# 111      42   luxembourg          #00042-SQUARE ANDRE
# 112     100   luxembourg  #00100-FORT NIEDERGRÜNEWALD
# 113      64   luxembourg               #00064-GRENIER
# 114      46   luxembourg     #00046-LONKECHER STROOSS
# 115      61   luxembourg               #00061-FRIEDEN
#
#                                                address  \
# 0    - LUDWIG VAN BEETHOVEN - RUE LUDWIG VAN BEETHO...
# 1    WEICKER - AVENUE JF KENNEDY / RUE ALPHONSE WEI...
# 2    FENTANGE "Hiehl" - RUE DE BETTEMBOURG DEVANT N°75
# 3    SERRA - AVENUE J.F. KENNEDY / CIRCUIT DE LA FO...
# ...
